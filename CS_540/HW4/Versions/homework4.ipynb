# %%
import csv 
import matplotlib.pyplot as plt

from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram, linkage


from pokemon_stats import*

data = load_data('pokemon.csv')
print(data)
dataset = []
for d in data:
        dataset.append(calculate_x_y(d))
print(dataset)
matrix = hac(dataset)
print(matrix)
# main()
print(test())
imshow_hac(dataset)
# print(random_x_y(10))
# Out:
# [OrderedDict([('#', 1), ('Name', 'Bulbasaur'), ('Type 1', 'Grass'), ('Type 2', 'Poison'), ('Total', 318), ('HP', 45), ('Attack', 49), ('Defense', 49), ('Sp. Atk', 65), ('Sp. Def', 65), ('Speed', 45)]), OrderedDict([('#', 2), ('Name', 'Ivysaur'), ('Type 1', 'Grass'), ('Type 2', 'Poison'), ('Total', 405), ('HP', 60), ('Attack', 62), ('Defense', 63), ('Sp. Atk', 80), ('Sp. Def', 80), ('Speed', 60)]), OrderedDict([('#', 3), ('Name', 'Venusaur'), ('Type 1', 'Grass'), ('Type 2', 'Poison'), ('Total', 525), ('HP', 80), ('Attack', 82), ('Defense', 83), ('Sp. Atk', 100), ('Sp. Def', 100), ('Speed', 80)]), OrderedDict([('#', 3), ('Name', 'VenusaurMega Venusaur'), ('Type 1', 'Grass'), ('Type 2', 'Poison'), ('Total', 625), ('HP', 80), ('Attack', 100), ('Defense', 123), ('Sp. Atk', 122), ('Sp. Def', 120), ('Speed', 80)]), OrderedDict([('#', 4), ('Name', 'Charmander'), ('Type 1', 'Fire'), ('Type 2', ''), ('Total', 309), ('HP', 39), ('Attack', 52), ('Defense', 43), ('Sp. Atk', 60), ('Sp. Def', 50), ('Speed', 65)]), OrderedDict([('#', 5), ('Name', 'Charmeleon'), ('Type 1', 'Fire'), ('Type 2', ''), ('Total', 405), ('HP', 58), ('Attack', 64), ('Defense', 58), ('Sp. Atk', 80), ('Sp. Def', 65), ('Speed', 80)]), OrderedDict([('#', 6), ('Name', 'Charizard'), ('Type 1', 'Fire'), ('Type 2', 'Flying'), ('Total', 534), ('HP', 78), ('Attack', 84), ('Defense', 78), ('Sp. Atk', 109), ('Sp. Def', 85), ('Speed', 100)]), OrderedDict([('#', 6), ('Name', 'CharizardMega Charizard X'), ('Type 1', 'Fire'), ('Type 2', 'Dragon'), ('Total', 634), ('HP', 78), ('Attack', 130), ('Defense', 111), ('Sp. Atk', 130), ('Sp. Def', 85), ('Speed', 100)]), OrderedDict([('#', 6), ('Name', 'CharizardMega Charizard Y'), ('Type 1', 'Fire'), ('Type 2', 'Flying'), ('Total', 634), ('HP', 78), ('Attack', 104), ('Defense', 78), ('Sp. Atk', 159), ('Sp. Def', 115), ('Speed', 100)]), OrderedDict([('#', 7), ('Name', 'Squirtle'), ('Type 1', 'Water'), ('Type 2', ''), ('Total', 314), ('HP', 44), ('Attack', 48), ('Defense', 65), ('Sp. Atk', 50), ('Sp. Def', 64), ('Speed', 43)]), OrderedDict([('#', 8), ('Name', 'Wartortle'), ('Type 1', 'Water'), ('Type 2', ''), ('Total', 405), ('HP', 59), ('Attack', 63), ('Defense', 80), ('Sp. Atk', 65), ('Sp. Def', 80), ('Speed', 58)]), OrderedDict([('#', 9), ('Name', 'Blastoise'), ('Type 1', 'Water'), ('Type 2', ''), ('Total', 530), ('HP', 79), ('Attack', 83), ('Defense', 100), ('Sp. Atk', 85), ('Sp. Def', 105), ('Speed', 78)]), OrderedDict([('#', 9), ('Name', 'BlastoiseMega Blastoise'), ('Type 1', 'Water'), ('Type 2', ''), ('Total', 630), ('HP', 79), ('Attack', 103), ('Defense', 120), ('Sp. Atk', 135), ('Sp. Def', 115), ('Speed', 78)]), OrderedDict([('#', 10), ('Name', 'Caterpie'), ('Type 1', 'Bug'), ('Type 2', ''), ('Total', 195), ('HP', 45), ('Attack', 30), ('Defense', 35), ('Sp. Atk', 20), ('Sp. Def', 20), ('Speed', 45)]), OrderedDict([('#', 11), ('Name', 'Metapod'), ('Type 1', 'Bug'), ('Type 2', ''), ('Total', 205), ('HP', 50), ('Attack', 20), ('Defense', 55), ('Sp. Atk', 25), ('Sp. Def', 25), ('Speed', 30)]), OrderedDict([('#', 12), ('Name', 'Butterfree'), ('Type 1', 'Bug'), ('Type 2', 'Flying'), ('Total', 395), ('HP', 60), ('Attack', 45), ('Defense', 50), ('Sp. Atk', 90), ('Sp. Def', 80), ('Speed', 70)]), OrderedDict([('#', 13), ('Name', 'Weedle'), ('Type 1', 'Bug'), ('Type 2', 'Poison'), ('Total', 195), ('HP', 40), ('Attack', 35), ('Defense', 30), ('Sp. Atk', 20), ('Sp. Def', 20), ('Speed', 50)]), OrderedDict([('#', 14), ('Name', 'Kakuna'), ('Type 1', 'Bug'), ('Type 2', 'Poison'), ('Total', 205), ('HP', 45), ('Attack', 25), ('Defense', 50), ('Sp. Atk', 25), ('Sp. Def', 25), ('Speed', 35)]), OrderedDict([('#', 15), ('Name', 'Beedrill'), ('Type 1', 'Bug'), ('Type 2', 'Poison'), ('Total', 395), ('HP', 65), ('Attack', 90), ('Defense', 40), ('Sp. Atk', 45), ('Sp. Def', 80), ('Speed', 75)]), OrderedDict([('#', 15), ('Name', 'BeedrillMega Beedrill'), ('Type 1', 'Bug'), ('Type 2', 'Poison'), ('Total', 495), ('HP', 65), ('Attack', 150), ('Defense', 40), ('Sp. At ...
# [(159, 159), (202, 203), (262, 263), (302, 323), (177, 132), (224, 181), (293, 241), (360, 274), (363, 271), (141, 173), (186, 219), (246, 284), (316, 314), (95, 100), (75, 130), (205, 190), (105, 90), (85, 120), (210, 185), (310, 185)]
# [[ 7.          8.          4.24264069  2.        ]
#  [15.         18.          7.07106781  2.        ]
#  [ 1.         21.         13.34166406  3.        ]
#  [13.         16.         14.14213562  2.        ]
#  [14.         17.         14.14213562  2.        ]
#  [ 5.         22.         14.56021978  4.        ]
#  [ 3.         12.         16.64331698  2.        ]
#  [23.         24.         22.36067977  4.        ]
#  [25.         10.         22.627417    5.        ]
#  [ 0.          9.         22.8035085   2.        ]
#  [ 2.         11.         26.40075756  2.        ]
#  [29.          4.         32.44996148  3.        ]
#  [30.          6.         38.01315562  3.        ]
#  [31.         28.         55.47071299  8.        ]
#  [32.         19.         58.52349955  4.        ]
#  [20.         26.         59.46427499  4.        ]
#  [35.         34.         68.24221567  8.        ]
#  [33.         27.         77.1038261  12.        ]
#  [37.         36.         84.85281374 20.        ]]
# [[ 7.          8.          4.24264069  2.        ]
#  [15.         18.          7.07106781  2.        ]
#  [ 1.         21.         13.34166406  3.        ]
#  [14.         17.         14.14213562  2.        ]
#  [13.         16.         14.14213562  2.        ]
#  [ 5.         22.         14.56021978  4.        ]
#  [ 3.         12.         16.64331698  2.        ]
#  [23.         24.         22.36067977  4.        ]
#  [10.         25.         22.627417    5.        ]
#  [ 0.          9.         22.8035085   2.        ]
#  [ 2.         11.         26.40075756  2.        ]
#  [ 4.         29.         32.44996148  3.        ]
#  [ 6.         30.         38.01315562  3.        ]
#  [28.         31.         55.47071299  8.        ]
#  [19.         32.         58.52349955  4.        ]
#  [20.         26.         59.46427499  4.        ]
#  [34.         35.         68.24221567  8.        ]
#  [27.         33.         77.1038261  12.        ]
#  [36.         37.         84.85281374 20.        ]]
# None
